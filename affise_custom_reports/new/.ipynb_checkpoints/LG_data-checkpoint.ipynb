# %%
import requests
import pandas as pd

# %%
date_from = '2021-08-01'
date_to = '2021-10-31'

req_url = f'https://leadgid.api.hasoffers.com/Apiv3/json?api_key=4dc79c63460150a918972cf84c9c4557ff0d063b1252d267fe50f9fcb5abf127&Target=Affiliate_Report&Method=getStats&fields[]=Stat.date&fields[]=Stat.affiliate_info3&fields[]=Stat.affiliate_info2&fields[]=Stat.affiliate_info1&fields[]=Stat.payout&fields[]=Stat.clicks&fields[]=Stat.offer_id&fields[]=Offer.name&filters[Stat.date][conditional]=BETWEEN&filters[Stat.date][values][]={date_from}&filters[Stat.date][values][]={date_to}'
req = requests.get(req_url).json()

# %%
conversion_list = []
columns = ['date', 'offer_name', 'offer_id', 'sub1', 'sub2', 'sub3', 'payout', 'clicks']

for item in req['response']['data']['data']:
    date = item['Stat']['date']
    offer_name = item['Offer']['name']
    offer_id = item['Stat']['offer_id']
    sub1 = item['Stat']['affiliate_info1']
    sub2 = item['Stat']['affiliate_info2']
    sub3 = item['Stat']['affiliate_info3']
    payout = item['Stat']['payout']
    clicks = item['Stat']['clicks']

    conversion_list.append([date, offer_name, offer_id, sub1, sub2, sub3, payout, clicks])

# %%
# conversion_list

# %%
df = pd.DataFrame(columns=columns, data=conversion_list)
df['date'] = pd.to_datetime(df['date'])
df['payout'] = pd.to_numeric(df['payout'])
df['clicks'] = df['clicks'].astype('int')
df['EPC'] = (df['payout'] / df['clicks']).round(2)
df['week'] = df['date'].dt.isocalendar().week
df.head()
# Out:
#         date                   offer_name offer_id sub1 sub2 sub3   payout  \
# 0 2021-08-01  VIVA деньги - онлайн выдача     5141  ppp            19200.0
# 1 2021-08-01    ТУРБОЗАЙМ - Выданный займ     2577   sm            11250.0
# 2 2021-08-01    Webbankir - выданный заём     3127   sm             5850.0
# 3 2021-08-01             Credit7 - выдача     4470   sm             6600.0
# 4 2021-08-01         BelkaCredit - выдача     4472   sm             5760.0
#
#    clicks    EPC  week
# 0     475  40.42    30
# 1     125  90.00    30
# 2     194  30.15    30
# 3     309  21.36    30
# 4     181  31.82    30

# %%
df
# Out:
#          date                                         offer_name offer_id  \
# 0  2021-08-01                        VIVA деньги - онлайн выдача     5141
# 1  2021-08-01                          ТУРБОЗАЙМ - Выданный займ     2577
# 2  2021-08-01                          Webbankir - выданный заём     3127
# 3  2021-08-01                                   Credit7 - выдача     4470
# 4  2021-08-01                               BelkaCredit - выдача     4472
# 5  2021-08-01             Moneyman - Выдача новому клиенту (VIP)     5024
# 6  2021-08-01                       Займер - выдача микрокредита     1621
# 7  2021-08-01  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 8  2021-08-01  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 9  2021-08-02                        VIVA деньги - онлайн выдача     5141
# 10 2021-08-02                          ТУРБОЗАЙМ - Выданный займ     2577
# 11 2021-08-02                          Webbankir - выданный заём     3127
# 12 2021-08-02                                   Credit7 - выдача     4470
# 13 2021-08-02                               BelkaCredit - выдача     4472
# 14 2021-08-02             Moneyman - Выдача новому клиенту (VIP)     5024
# 15 2021-08-02                       Займер - выдача микрокредита     1621
# 16 2021-08-02  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 17 2021-08-02  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 18 2021-08-03                        VIVA деньги - онлайн выдача     5141
# 19 2021-08-03                        VIVA деньги - онлайн выдача     5141
# 20 2021-08-03                          ТУРБОЗАЙМ - Выданный займ     2577
# 21 2021-08-03                          Webbankir - выданный заём     3127
# 22 2021-08-03                                   Credit7 - выдача     4470
# 23 2021-08-03                               BelkaCredit - выдача     4472
# 24 2021-08-03             Moneyman - Выдача новому клиенту (VIP)     5024
# 25 2021-08-03  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 26 2021-08-03  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 27 2021-08-04                        VIVA деньги - онлайн выдача     5141
# 28 2021-08-04                          ТУРБОЗАЙМ - Выданный займ     2577
# 29 2021-08-04                          Webbankir - выданный заём     3127
# 30 2021-08-04                                   Credit7 - выдача     4470
# 31 2021-08-04                               BelkaCredit - выдача     4472
# 32 2021-08-04             Moneyman - Выдача новому клиенту (VIP)     5024
# 33 2021-08-04  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 34 2021-08-04  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 35 2021-08-05                        VIVA деньги - онлайн выдача     5141
# 36 2021-08-05                    Guru Cash - Выдача + Повторная      5395
# 37 2021-08-05                          ТУРБОЗАЙМ - Выданный займ     2577
# 38 2021-08-05                          Webbankir - выданный заём     3127
# 39 2021-08-05                                   Credit7 - выдача     4470
# 40 2021-08-05                               BelkaCredit - выдача     4472
# 41 2021-08-05             Moneyman - Выдача новому клиенту (VIP)     5024
# 42 2021-08-05  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 43 2021-08-05  Е - капуста - Заявка заполненная клиентом с хо...     1658
# 44 2021-08-06                        VIVA деньги - онлайн выдача     5141
# 45 2021-08-06                    Guru Cash - Выдача + Повторная      5395
# 46 2021-08-06                          ТУРБОЗАЙМ - Выданный займ     2577
# 47 2021-08-06                          Webbankir - выданный заём     3127
# 48 2021-08-06                                   Credit7 - выдача     4470
# 49 2021-08-06                               BelkaCredit - выдача     4472
#
#      sub1    sub2 sub3   payout  clicks     EPC  week
# 0     ppp               19200.0     475   40.42    30
# 1      sm               11250.0     125   90.00    30
# 2      sm                5850.0     194   30.15    30
# 3      sm                6600.0     309   21.36    30
# 4      sm                5760.0     181   31.82    30
# 5      sm               12800.0     111  115.32    30
# 6     sm1                1750.0       5  350.00    30
# 7      sm  kap_td       16400.0     114  143.86    30
# 8      sm  kap_yt        6150.0      85   72.35    30
# 9     ppp               16000.0     454   35.24    31
# 10     sm                7500.0     106   70.75    31
# 11     sm                1250.0     135    9.26    31
# 12     sm               13200.0     278   47.48    31
# 13     sm                4320.0     135   32.00    31
# 14     sm               19200.0     103  186.41    31
# 15    sm1                   0.0       2    0.00    31
# 16     sm  kap_td        8200.0      99   82.83    31
# 17     sm  kap_yt       12300.0      62  198.39    31
# 18                       3200.0       0     inf    31
# 19    ppp               28800.0     497   57.95    31
# 20     sm                3750.0     123   30.49    31
# 21     sm                2100.0     147   14.29    31
# 22     sm                8800.0     280   31.43    31
# 23     sm                4320.0     149   28.99    31
# 24     sm                   0.0      89    0.00    31
# 25     sm  kap_td       10250.0     100  102.50    31
# 26     sm  kap_yt        2050.0      56   36.61    31
# 27    ppp               32000.0     472   67.80    31
# 28     sm                8750.0     143   61.19    31
# 29     sm                7050.0     179   39.39    31
# 30     sm               17600.0     416   42.31    31
# 31     sm                5760.0     214   26.92    31
# 32     sm                9600.0     128   75.00    31
# 33     sm  kap_td       28700.0     121  237.19    31
# 34     sm  kap_yt        4100.0      97   42.27    31
# 35    ppp               19200.0     500   38.40    31
# 36  sitbz                   0.0      41    0.00    31
# 37     sm                3750.0     133   28.20    31
# 38     sm                3350.0     153   21.90    31
# 39     sm               28600.0     362   79.01    31
# 40     sm                7200.0     180   40.00    31
# 41     sm               12800.0     126  101.59    31
# 42     sm  kap_td       14350.0     103  139.32    31
# 43     sm  kap_yt           0.0      28    0.00    31
# 44    ppp               22400.0     453   49.45    31
# 45  sitbz                2400.0       4  600.00    31
# 46     sm                8750.0     133   65.79    31
# 47     sm                6300.0     128   49.22    31
# 48     sm               13200.0     295   44.75    31
# 49     sm                2880.0     140   20.57    31
