# %%
import pandas as pd

# %%
df = pd.read_csv('LIME2021.csv')
# Out:
# /Users/mikhail/PycharmProjects/affise/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (2,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
leads = df.query('partner == "LEADS" & loan_category == "new"').reset_index()

# %%
leads
# Out:
#         index  Unnamed: 0        date action_id                  click_id  \
# 0          44          44  2021-12-07   5648319  61ae4caa190e9c0001f62ecc
# 1          52          52  2021-12-07   5833587  61ad82c6190e9c0001f57a94
# 2          66          66  2021-12-07   5691251  61af3bb4190e9c0001f6b66d
# 3         129         129  2021-12-07   5840080  61af2c08190e9c0001f6a85f
# 4         202         202  2021-12-07   5765585  61af3177190e9c0001f6ad4b
# ...       ...         ...         ...       ...                       ...
# 43202  737575      741536  2021-01-01   4777675  5feed67a00d186000187258b
# 43203  737610      741571  2021-01-01   4777611  5feec23a00d1860001872267
# 43204  737631      741592  2021-01-01   4777293  5fee9d3e00d1860001871e86
# 43205  737654      741615  2021-01-01   4776603  5fed7af100d186000186f058
# 43206  737675      741636  2021-01-01   3374021  5fee5acc00d1860001871835
#
#           status  offer_id               goal  payouts partner  ...     sub2  \
# ...
