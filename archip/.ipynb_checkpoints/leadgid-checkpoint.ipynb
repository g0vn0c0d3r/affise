# %%
import pandas as pd
import requests

# %%
URL = 'https://stat.leedz.me/api/stat/react/get_raw_grouped_data'

start_date
end_date

# %%
data = requests.get('https://stat.leedz.me/api/stat/react/
                    'get_raw_grouped_data?start_date=2022-01-01&end_date=2022-01-31&tkn=ZuuperUzer123')
# Out:
#   File "/var/folders/d_/6kg_s1r949z5r4ysvdqsp9fw0000gn/T/ipykernel_58932/3507638623.py", line 1
#     data = requests.get('https://stat.leedz.me/api/stat/react/
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
data.json()
# Out:
# {'data': [{'date': '2022-01-02',
#    'date_ts': 1641070800,
#    'month': 1,
#    'week': 52,
#    'sub1': 'sm',
#    'sub2': 'd0q1',
#    'sub3': 'webbankir_check',
#    'sub4': '',
#    'cost': 2146.02,
#    'sms_count': 780,
#    'payout': 6800.0,
#    'net_margin': 4653.98},
#   {'date': '2022-01-02',
#    'date_ts': 1641070800,
#    'month': 1,
#    'week': 52,
#    'sub1': 'sm',
#    'sub2': 'd1q1',
#    'sub3': 'vitrina',
#    'sub4': '',
#    'cost': 2513.27,
#    'sms_count': 913,
#    'payout': 10600.0,
#    'net_margin': 8086.73},
#   {'date': '2022-01-02',
#    'date_ts': 1641070800,
#    'month': 1,
#    'week': 52,
#    'sub1': 'sm',
#    'sub2': 'd0q3',
#    'sub3': '',
#    'sub4': '',
#    'cost': 4333.18,
#    'sms_count': 1575,
#    'payout': 10400.0,
#    'net_margin': 6066.82},
#   {'date': '2022-01-02',
#    'date_ts': 1641070800,
#    'month': 1,
#    'week': 52,
#    'sub1': 'sm',
#    'sub2': 'd0q2',
#    'sub3': '',
#    'sub4': '',
#    'cost': 4400.09,
# ...
